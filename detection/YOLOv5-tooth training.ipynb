# %%
import platform

print(platform.system())
# !df -h
# Out:
# Linux
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          79G   27G   52G  34% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.1G  885M  55% /usr/sbin/docker-init
# /dev/sda1        50G   29G   22G  58% /opt/bin/.nvidia
# tmpfs           6.4G   40K  6.4G   1% /var/colab
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# !nvidia-smi
# Out:
# Mon Oct  9 09:34:08 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !cat /proc/cpuinfo

# %%
# !cat /proc/meminfo

# %% [markdown]
# Mengakses Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Membuat symbolic link atau shorcut ke Gdrive

# %%
# !ln -s /content/drive/My\ Drive/PALJ/COBA-YOLO/YOLOV5 /content/drive-yolo
# !ln -s /content/drive/My\ Drive/PALJ/YOLOV5 /content/drive-yolo

# %%
rm /content/drive-yolo

# %% [markdown]
# Setup Comet
# *unnecessary

# %%
# %pip install comet_ml

from comet_ml import Experiment
from comet_ml.integration.pytorch import log_model

experiment = Experiment(
  api_key = "xRRBhPUEV1E2gNMWPs2Y17rEW",
  project_name = "yolov5",
  workspace="qsaifudin"
)

hyper_params = {
   "learning_rate": 0.5,
   "steps": 100000,
   "batch_size": 50,
}
experiment.log_parameters(hyper_params)

# %%
Masuk ke folder GDrive

# %%
ls /content/drive-yolo/
# Out:
# 'Copy of YOLOv5-tooth training.ipynb'   Tes-Apple/
#  datasets/                              yolov5/
#  log-comet/                            'YOLOv5-tooth training.ipynb'

# %%
# %cd /content/drive-yolo/yolov5/yolov5
# Out:
# /content/drive/.shortcut-targets-by-id/1-EzGuejIMtXGP1O5kkr1ta_fKEOEsc8w/YOLOV5/yolov5/yolov5

# %%
ls
# Out:
# benchmarks.py    detect.py   __pycache__/      segment/        val.py
# CITATION.cff     export.py   README.md         setup.cfg
# classify/        hubconf.py  README.zh-CN.md   train.py
# CONTRIBUTING.md  LICENSE     requirements.txt  tutorial.ipynb
# data/            models/     runs/             utils/

# %%
Download file yolov5

# %%
#clone YOLOv5 and
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16003, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 16003 (delta 21), reused 20 (delta 13), pack-reused 15967
# Receiving objects: 100% (16003/16003), 14.60 MiB | 16.16 MiB/s, done.
# Resolving deltas: 100% (10987/10987), done.

# %%
Masuk ke folder yolov5

# %%
cd yolov5
# Out:
# /content/drive/My Drive/PALJ/COBA-YOLO/YOLOV5/yolov5/yolov5

# %%
ls
# Out:
# benchmarks.py    detect.py   __pycache__/      segment/        val.py
# CITATION.cff     export.py   README.md         setup.cfg
# classify/        hubconf.py  README.zh-CN.md   train.py
# CONTRIBUTING.md  LICENSE     requirements.txt  tutorial.ipynb
# data/            models/     runs/             utils/

# %%
# %cd /content/drive-yolo/yolov5
# %cd /content/yolov5
# %pwd
# %ls
# Out:
# /content/drive/My Drive/PALJ/COBA-YOLO/YOLOV5/yolov5
# benchmarks.py    Deteksi-Gigi--5/  README.zh-CN.md   utils/
# best-m-new.pt    export.py         requirements.txt  val.py
# CITATION.cff     hubconf.py        runs/             yolov5m.pt
# classify/        LICENSE           segment/          yolov5s.pt
# CONTRIBUTING.md  models/           setup.cfg
# data/            __pycache__/      train.py
# detect.py        README.md         tutorial.ipynb

# %%
Install-install

# %%
# %cd yolov5
# %pip install -qr requirements.txt  # install
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 27.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
# Setup complete. Using torch 2.0.1+cu118 (Tesla T4)

# %%
# !pip install comet_ml  # 1. install

from comet_ml import Experiment
from comet_ml.integration.pytorch import log_model

experiment = Experiment(
  api_key = "xRRBhPUEV1E2gNMWPs2Y17rEW",
  project_name = "yolov5-s",
  workspace="qsaifudin"
)

# %%
Setup folder dataset

# %%
# set up environment
# os.environ["DATASET_DIRECTORY"] = "/content/drive/MyDrive/PALJ/COBA-YOLO/YOLOV5"
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %% [markdown]
# Download dataset dari roboflow

# %%
rm -r datasets/Deteksi-Gigi--10/

# %%
# rf = Roboflow(api_key="eYCohZWd9scysDJjEr7p",model_format="yolov5", notebook="ultralytics")
# from roboflow import Roboflow
# rf = Roboflow(api_key="eYCohZWd9scysDJjEr7p")
# project = rf.workspace("politeknik-elektronika-negeri-surabaya-hclhy").project("deteksi-gigi")
# dataset = project.version(5).download("yolov5")

# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="eYCohZWd9scysDJjEr7p")
# project = rf.workspace("politeknik-elektronika-negeri-surabaya-hclhy").project("deteksi-gigi")
# dataset = project.version(6).download("yolov5")

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="eYCohZWd9scysDJjEr7p")
project = rf.workspace("politeknik-elektronika-negeri-surabaya-hclhy").project("deteksi-gigi")
dataset = project.version(12).download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/datasets/Deteksi-Gigi--12 in yolov5pytorch:: 100%|██████████| 2764/2764 [00:00<00:00, 2932.88it/s]

# %%
Proses training

# %%
print(dataset.location)
# Out:
# /content/datasets/Deteksi-Gigi--11

# %%
pwd
# Out:
# '/content/drive/.shortcut-targets-by-id/1-EzGuejIMtXGP1O5kkr1ta_fKEOEsc8w/YOLOV5/yolov5/yolov5'

# %%
# !python train.py --img {imgSize} --batch {batchSize} --epochs {epochsSize} --data {dataset.location}/data.yaml --weights yolov5s.pt --cache ram
# !python train.py \
--img 608 \
--batch 3 \
--epochs 50 \
--data {dataset.location}/data.yaml \
--weights yolov5m.pt \
--cache ram
# --weights ../best-m-new.pt \
# !python train.py --img 1280 --batch 50 --epochs 900 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache ram

# !python train.py --img 640 --batch 32 --epochs 600 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5m.pt, cfg=, data=/content/datasets/Deteksi-Gigi--12/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=3, imgsz=608, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
ls
# Out:
# benchmarks.py    detect.py         models/           runs/           utils/
# CITATION.cff     Deteksi-Gigi--5/  __pycache__/      segment/        val.py
# classify/        export.py         README.md         setup.cfg       yolov5m.pt
# CONTRIBUTING.md  hubconf.py        README.zh-CN.md   train.py        yolov5s.pt
# data/            LICENSE           requirements.txt  tutorial.ipynb

# %%
*unnecessary

# %%
log_model(experiment, model, model_name="TheModel")

# %%
Show grafik

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 27665), started 0:06:15 ago. (Use '!kill 27665' to kill it.)

# %% [markdown]
# Proses testing

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 900 --conf 0.1 --source {dataset.location}/test/images
# !python detect.py --weights best-aby.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['runs/train/exp7/weights/best.pt'], source=/content/datasets/Deteksi-Gigi--5/test/images, data=data/coco128.yaml, imgsz=[900, 900], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=1, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-185-g2334aa7 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7096429 parameters, 0 gradients, 16.0 GFLOPs
# WARNING ⚠️ --img-size [900, 900] must be multiple of max stride 32, updating to [928, 928]
# ...

# %% [markdown]
# Lihat gambar setelah di testing

# %%
# display inference on ALL test images
import glob
from IPython.display import Image, display

# for imageName in glob.glob('/content/yolov5/runs/detect/' + expName + '/*.jpg'): #assuming JPG
#     display(Image(filename=imageName))
#     print("\n")
for imageName in glob.glob('/content/yolov5/runs/detect/' + expName + '/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# *unnecessary

# %%
# %ls
# !cp ./ /content/drive/MyDrive/PALJ/COBA-YOLO/YOLOV5
# !cp -r . /content/drive/MyDrive/PALJ/COBA-YOLO/YOLOV5/yolov5/

# %% [markdown]
# *unnecessary

# %%
#export your model's weights for future use
from google.colab import files
files.download('./runs/train/exp/weights/best.pt')

# %% [markdown]
# *unnecessary

# %%
import shutil
import os

# Set the path to the folder containing the files
# folder_path = './runs/detect/' + expName + '/'
folder_path = './'

# Get a list of all files in the folder
file_list = os.listdir(folder_path)

# Create a ZIP file to store the folder contents
shutil.make_archive('/content/folder_download', 'zip', folder_path)

# Download the ZIP file
from google.colab import files
files.download('/content/folder_download.zip')

# %%
# !python val.py --weights /content/drive-yolo/yolov5/runs/train/exp10-m2/weights/last.pt --data /content/datasets/Deteksi-Gigi--6/data.yaml --img 640
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# val: data=/content/datasets/Deteksi-Gigi--6/data.yaml, weights=['/content/drive-yolo/yolov5/runs/train/exp10-m2/weights/last.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# ...

# %%
ls /content
# Out:
# datasets/  drive/  drive-yolo@  sample_data/
