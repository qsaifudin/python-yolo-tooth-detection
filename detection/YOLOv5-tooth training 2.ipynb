# %% [markdown]
# Mengakses Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Membuat symbolic link atau shorcut ke Gdrive

# %%
# !ln -s /content/drive/My\ Drive/PALJ/YOLOV5 /content/drive-yolo

# %% [markdown]
# Setup Comet
# *unnecessary

# %%
Masuk ke folder GDrive

# %%
ls /content/drive-yolo/
# Out:
# 'Copy of YOLOv5-tooth training.ipynb'   test/
#  datasets/                              train/
#  log-comet/                             valid/
#  README.dataset.txt                     yolov5/
#  README.roboflow.txt                   'YOLOv5-tooth training 2.ipynb'
#  Tes-Apple/                            'YOLOv5-tooth training.ipynb'

# %%
# %cd /content/drive-yolo/yolov5/yolov5
# Out:
# /content/drive/.shortcut-targets-by-id/1-EzGuejIMtXGP1O5kkr1ta_fKEOEsc8w/YOLOV5/yolov5/yolov5

# %%
ls
# Out:
# benchmarks.py    detect.py   __pycache__/      segment/        val.py
# CITATION.cff     export.py   README.md         setup.cfg
# classify/        hubconf.py  README.zh-CN.md   train.py
# CONTRIBUTING.md  LICENSE     requirements.txt  tutorial.ipynb
# data/            models/     runs/             utils/

# %%
Download file yolov5

# %%
#clone YOLOv5 and
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16003, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 16003 (delta 21), reused 20 (delta 13), pack-reused 15967
# Receiving objects: 100% (16003/16003), 14.60 MiB | 16.16 MiB/s, done.
# Resolving deltas: 100% (10987/10987), done.

# %%
Masuk ke folder yolov5

# %%
ls
# Out:
# 'Copy of YOLOv5-tooth training.ipynb'   yolov5/
#  datasets/                             'YOLOv5-tooth training 2.ipynb'
#  log-comet/                            'YOLOv5-tooth training.ipynb'
#  Tes-Apple/

# %%
# %cd /content/drive-yolo/yolov5/yolov5
# %cd /content/yolov5
# %pwd
# %ls
# Out:
# /content/drive/.shortcut-targets-by-id/1-EzGuejIMtXGP1O5kkr1ta_fKEOEsc8w/YOLOV5/yolov5/yolov5
# benchmarks.py    detect.py   __pycache__/      segment/        val.py
# CITATION.cff     export.py   README.md         setup.cfg       yolov5m.pt
# classify/        hubconf.py  README.zh-CN.md   train.py
# CONTRIBUTING.md  LICENSE     requirements.txt  tutorial.ipynb
# data/            models/     runs/             utils/

# %%
Install-install

# %%
# %cd yolov5
# %pip install -qr requirements.txt  # install
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 21.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.0 MB/s eta 0:00:00
# Setup complete. Using torch 2.0.1+cu118 (CPU)

# %%
Setup folder dataset

# %%
# set up environment
# os.environ["DATASET_DIRECTORY"] = "/content/drive/MyDrive/PALJ/COBA-YOLO/YOLOV5"
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %% [markdown]
# Download dataset dari roboflow

# %%
ls
# Out:
# Deteksi-Gigi--12/  drive/  drive-yolo@  sample_data/

# %%
# rf = Roboflow(api_key="eYCohZWd9scysDJjEr7p",model_format="yolov5", notebook="ultralytics")
# from roboflow import Roboflow
# rf = Roboflow(api_key="eYCohZWd9scysDJjEr7p")
# project = rf.workspace("politeknik-elektronika-negeri-surabaya-hclhy").project("deteksi-gigi")
# dataset = project.version(5).download("yolov5")

# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="eYCohZWd9scysDJjEr7p")
# project = rf.workspace("politeknik-elektronika-negeri-surabaya-hclhy").project("deteksi-gigi")
# dataset = project.version(6).download("yolov5")

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="eYCohZWd9scysDJjEr7p")
project = rf.workspace("politeknik-elektronika-negeri-surabaya-hclhy").project("deteksi-gigi")
dataset = project.version(12).download("yolov5")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.7)
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.23.5)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.4.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: supervision in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.15.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.6)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.43.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.0)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.3)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in /content/datasets/Deteksi-Gigi--12 to yolov5pytorch:: 100%|██████████| 45692/45692 [00:02<00:00, 20992.75it/s]
# Extracting Dataset Version Zip to /content/datasets/Deteksi-Gigi--12 in yolov5pytorch:: 100%|██████████| 2764/2764 [00:01<00:00, 2470.94it/s]

# %%
Proses training

# %%
print(dataset.location)
# Out:
# /content/datasets/Deteksi-Gigi--12

# %%
ls
# Out:
# benchmarks.py    Deteksi-Gigi--5/  README.zh-CN.md   utils/
# best-m-new.pt    export.py         requirements.txt  val.py
# CITATION.cff     hubconf.py        runs/             yolov5m.pt
# classify/        LICENSE           segment/          yolov5s.pt
# CONTRIBUTING.md  models/           setup.cfg
# data/            __pycache__/      train.py
# detect.py        README.md         tutorial.ipynb

# %%
# !python train.py --img {imgSize} --batch {batchSize} --epochs {epochsSize} --data {dataset.location}/data.yaml --weights yolov5s.pt --cache ram
# !python train.py \
--img 608 \
--batch 40 \
--epochs 700 \
--data {dataset.location}/data.yaml \
--weights yolov5m.pt \
--cache ram
# !python train.py --img 1280 --batch 50 --epochs 900 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache ram

# !python train.py --img 640 --batch 32 --epochs 600 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5m.pt, cfg=, data=/content/datasets/Deteksi-Gigi--12/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=700, batch_size=40, imgsz=608, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 85.0MB/s]
# Overriding model.yaml nc=80 with nc=32
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1    149517  models.yolo.Detect                      [32, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# Model summary: 291 layers, 20996589 parameters, 20996589 gradients, 48.6 GFLOPs
#
# Transferred 475/481 items from yolov5m.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 79 weight(decay=0.0), 82 weight(decay=0.000625), 82 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/datasets/Deteksi-Gigi--12/train/labels... 1276 images, 0 backgrounds, 0 corrupt: 100% 1276/1276 [00:00<00:00, 1549.54it/s]
# train: New cache created: /content/datasets/Deteksi-Gigi--12/train/labels.cache
# train: Caching images (0.7GB ram): 100% 1276/1276 [00:03<00:00, 383.70it/s]
# val: Scanning /content/datasets/Deteksi-Gigi--12/valid/labels... 55 images, 0 backgrounds, 0 corrupt: 100% 55/55 [00:00<00:00, 498.68it/s]
# val: New cache created: /content/datasets/Deteksi-Gigi--12/valid/labels.cache
# val: Caching images (0.0GB ram): 100% 55/55 [00:00<00:00, 95.25it/s]
#
# AutoAnchor: 5.56 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp7/labels.jpg...
# Image sizes 608 train, 608 val
# Using 2 dataloader workers
# Logging results to runs/train/exp7
# Starting training for 700 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/699      13.6G     0.1038      0.212    0.08671       1994        608: 100% 32/32 [00:52<00:00,  1.63s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:05<00:00,  5.63s/it]
#                    all         55       1630     0.0188      0.027      0.011    0.00283
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/699      13.6G    0.08048     0.1652    0.08083       1924        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.86s/it]
#                    all         55       1630     0.0334       0.21     0.0419     0.0117
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/699      13.6G    0.07516     0.1677     0.0759       2288        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.77s/it]
#                    all         55       1630      0.277      0.205     0.0788     0.0275
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/699      13.6G    0.07153     0.1624    0.07271       1997        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.69s/it]
#                    all         55       1630      0.232      0.254      0.106     0.0411
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/699      13.6G      0.067     0.1583    0.06948       2373        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.81s/it]
#                    all         55       1630     0.0767      0.275      0.105     0.0402
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/699      13.6G    0.06321     0.1571    0.06616       2050        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.83s/it]
#                    all         55       1630     0.0923      0.623      0.197     0.0866
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/699      13.6G    0.06067     0.1513    0.06265       1946        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.82s/it]
#                    all         55       1630      0.806      0.174      0.262     0.0921
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/699      13.6G    0.06163      0.149    0.05961       2050        608: 100% 32/32 [00:36<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.78s/it]
#                    all         55       1630      0.295      0.366      0.336      0.174
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/699      13.6G    0.05711     0.1496    0.05667       1928        608: 100% 32/32 [00:38<00:00,  1.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.76s/it]
#                    all         55       1630      0.163      0.579      0.279     0.0897
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/699      13.6G    0.05846     0.1463     0.0544       2190        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:04<00:00,  4.12s/it]
#                    all         55       1630      0.227      0.287      0.261      0.107
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/699      13.6G    0.05568     0.1448    0.05235       1855        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.82s/it]
#                    all         55       1630      0.261      0.525       0.41      0.193
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/699      13.6G    0.05686     0.1431    0.05064       2152        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.81s/it]
#                    all         55       1630       0.28      0.613      0.508      0.256
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/699      13.6G    0.05574     0.1411    0.04906       1862        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.91s/it]
#                    all         55       1630      0.266       0.56      0.474      0.262
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/699      13.6G    0.05356      0.142    0.04736       2150        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:04<00:00,  4.19s/it]
#                    all         55       1630      0.246       0.36      0.293      0.133
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/699      13.6G    0.05378     0.1402    0.04613       2116        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.69s/it]
#                    all         55       1630      0.315      0.618      0.573      0.326
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/699      13.6G    0.05412     0.1383    0.04489       2079        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.82s/it]
#                    all         55       1630      0.362      0.642      0.592      0.358
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/699      13.6G     0.0542     0.1392    0.04371       2014        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.62s/it]
#                    all         55       1630      0.387      0.658      0.624      0.365
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/699      13.6G    0.05225     0.1377    0.04243       2292        608: 100% 32/32 [00:37<00:00,  1.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.55s/it]
#                    all         55       1630      0.406      0.657      0.648      0.384
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/699      13.6G    0.05228     0.1333    0.04132       1938        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:04<00:00,  4.09s/it]
#                    all         55       1630      0.336      0.469      0.413      0.239
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/699      13.6G    0.05248     0.1361    0.04007       2076        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.71s/it]
#                    all         55       1630      0.448      0.676      0.665      0.412
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/699      13.6G    0.05095      0.136    0.03861       2018        608: 100% 32/32 [00:38<00:00,  1.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.88s/it]
#                    all         55       1630      0.488      0.649      0.655      0.328
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/699      13.6G    0.05284      0.135    0.03735       2469        608: 100% 32/32 [00:39<00:00,  1.22s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.69s/it]
#                    all         55       1630      0.548      0.689      0.714      0.401
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/699      13.6G    0.05232     0.1343    0.03589       2344        608: 100% 32/32 [00:36<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/1 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 3.250s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:04<00:00,  4.13s/it]
#                    all         55       1630      0.512      0.459      0.457      0.197
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/699      13.6G    0.05184      0.133     0.0347       2263        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.16s/it]
#                    all         55       1630      0.586      0.745       0.77      0.415
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/699      13.6G    0.05071      0.133    0.03368       2283        608: 100% 32/32 [00:36<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.78s/it]
#                    all         55       1630      0.553      0.751      0.745      0.469
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/699      13.6G    0.05051     0.1294    0.03238       1901        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.85s/it]
#                    all         55       1630      0.667      0.744      0.804      0.512
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/699      13.6G    0.05046     0.1315    0.03136       2356        608: 100% 32/32 [00:38<00:00,  1.20s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.03s/it]
#                    all         55       1630      0.678      0.775      0.815      0.515
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/699      13.6G    0.05035     0.1321    0.03034       1713        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.79s/it]
#                    all         55       1630      0.632      0.782      0.811      0.519
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/699      13.6G    0.05052     0.1298    0.02967       2229        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.07s/it]
#                    all         55       1630      0.689      0.791      0.853       0.56
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/699      13.6G    0.05016     0.1309    0.02908       2188        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.24s/it]
#                    all         55       1630      0.675      0.805      0.846      0.545
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/699      13.6G    0.05074     0.1304    0.02829       2211        608: 100% 32/32 [00:37<00:00,  1.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.94s/it]
#                    all         55       1630      0.684       0.81      0.845      0.562
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/699      13.6G    0.04945     0.1321    0.02801       2370        608: 100% 32/32 [00:37<00:00,  1.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.43s/it]
#                    all         55       1630      0.647      0.784      0.821      0.508
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/699      13.6G    0.04925      0.127    0.02725       2184        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.33s/it]
#                    all         55       1630      0.714      0.846      0.867      0.556
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/699      13.6G    0.04829     0.1295    0.02675       1857        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.03s/it]
#                    all         55       1630       0.71      0.842      0.867      0.527
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/699      13.6G    0.05014     0.1278    0.02616       2467        608: 100% 32/32 [00:36<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.38s/it]
#                    all         55       1630      0.731      0.825      0.877      0.467
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/699      13.6G    0.04989     0.1282    0.02576       2265        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.75s/it]
#                    all         55       1630       0.77      0.864      0.889      0.509
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/699      13.6G    0.04817     0.1265    0.02529       2177        608: 100% 32/32 [00:36<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.18s/it]
#                    all         55       1630      0.742      0.863       0.89      0.539
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/699      13.6G    0.04854     0.1247    0.02498       2083        608: 100% 32/32 [00:35<00:00,  1.10s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:03<00:00,  3.06s/it]
#                    all         55       1630      0.781      0.863      0.901      0.551
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/699      13.6G    0.04942     0.1293    0.02481       2142        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.76s/it]
#                    all         55       1630      0.807      0.882      0.913      0.604
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/699      13.6G    0.04906     0.1277    0.02421       2441        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.62s/it]
#                    all         55       1630      0.775      0.831      0.874      0.565
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/699      13.6G    0.04821     0.1277    0.02416       2476        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.98s/it]
#                    all         55       1630      0.814      0.871       0.92      0.595
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/699      13.6G    0.04791     0.1249    0.02349       2200        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.71s/it]
#                    all         55       1630      0.815      0.891      0.917      0.592
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/699      13.6G    0.04808     0.1258    0.02316       2461        608: 100% 32/32 [00:37<00:00,  1.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.68s/it]
#                    all         55       1630      0.834      0.907      0.931      0.616
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/699      13.6G    0.04857     0.1222    0.02291       1964        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.71s/it]
#                    all         55       1630      0.856      0.913      0.942      0.615
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/699      13.6G    0.04757     0.1246     0.0227       1999        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.73s/it]
#                    all         55       1630      0.847       0.92      0.947      0.608
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/699      13.6G    0.04859     0.1273    0.02248       2368        608: 100% 32/32 [00:38<00:00,  1.20s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.72s/it]
#                    all         55       1630      0.856      0.907      0.942       0.58
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/699      13.6G    0.04763     0.1231    0.02215       1996        608: 100% 32/32 [00:35<00:00,  1.10s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.26s/it]
#                    all         55       1630      0.865      0.915      0.947      0.568
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/699      13.6G    0.04845     0.1274    0.02211       2441        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.68s/it]
#                    all         55       1630      0.893      0.931      0.957      0.611
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/699      13.6G    0.04854     0.1263    0.02175       2217        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.80s/it]
#                    all         55       1630      0.864      0.908      0.944      0.556
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/699      13.6G    0.04711     0.1237    0.02135       2343        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.73s/it]
#                    all         55       1630      0.897      0.929      0.959      0.656
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/699      13.6G    0.04747      0.124    0.02141       1883        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.78s/it]
#                    all         55       1630      0.841      0.891      0.937      0.633
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/699      13.6G    0.04739     0.1226    0.02111       1980        608: 100% 32/32 [00:36<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.40s/it]
#                    all         55       1630      0.892       0.93      0.963      0.654
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/699      13.6G    0.04623     0.1213    0.02079       2122        608: 100% 32/32 [00:36<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.22s/it]
#                    all         55       1630      0.895      0.935      0.962      0.643
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/699      13.6G    0.04753     0.1221    0.02055       2375        608: 100% 32/32 [00:37<00:00,  1.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all         55       1630      0.904      0.935      0.968      0.635
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/699      13.6G    0.04614      0.119    0.02035       1993        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.59s/it]
#                    all         55       1630      0.886      0.923      0.954      0.635
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/699      13.6G    0.04705     0.1203    0.02015       2026        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.59s/it]
#                    all         55       1630      0.844      0.887      0.936      0.629
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/699      13.6G    0.04772     0.1214    0.02006       2030        608: 100% 32/32 [00:37<00:00,  1.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.55s/it]
#                    all         55       1630        0.9      0.933      0.967      0.662
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/699      13.6G    0.04664     0.1191    0.01985       2260        608: 100% 32/32 [00:35<00:00,  1.10s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.64s/it]
#                    all         55       1630      0.909      0.943      0.966       0.63
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/699      13.6G    0.04686     0.1172    0.01972       2023        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.20s/it]
#                    all         55       1630      0.873      0.905      0.943      0.632
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/699      13.6G    0.04617     0.1175    0.01961       2062        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.01s/it]
#                    all         55       1630      0.896      0.932      0.962      0.661
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/699      13.6G    0.04547     0.1199    0.01937       2269        608: 100% 32/32 [00:36<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.62s/it]
#                    all         55       1630      0.894      0.916       0.96      0.649
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/699      13.6G    0.04605      0.118    0.01947       2074        608: 100% 32/32 [00:37<00:00,  1.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all         55       1630      0.911      0.934      0.968      0.657
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/699      13.6G    0.04706     0.1209    0.01934       2265        608: 100% 32/32 [00:36<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.63s/it]
#                    all         55       1630      0.917      0.931      0.966       0.67
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/699      13.6G      0.046     0.1179    0.01929       1792        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.64s/it]
#                    all         55       1630      0.915      0.943      0.964      0.647
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/699      13.6G    0.04513      0.117     0.0191       2089        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.65s/it]
#                    all         55       1630      0.916      0.945      0.965      0.653
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/699      13.6G    0.04585     0.1184    0.01895       1922        608: 100% 32/32 [00:36<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.54s/it]
#                    all         55       1630      0.919      0.947      0.971      0.661
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/699      13.6G    0.04483     0.1177     0.0186       1882        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.65s/it]
#                    all         55       1630      0.905      0.934      0.959      0.569
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/699      13.6G    0.04583     0.1165    0.01852       2119        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.60s/it]
#                    all         55       1630      0.909      0.926      0.959      0.612
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/699      13.6G    0.04546     0.1169    0.01858       2297        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.57s/it]
#                    all         55       1630      0.896      0.915      0.953      0.596
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/699      13.6G    0.04577     0.1173    0.01847       2033        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.77s/it]
#                    all         55       1630      0.887      0.885      0.943      0.588
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/699      13.6G    0.04465      0.115    0.01814       1870        608: 100% 32/32 [00:37<00:00,  1.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.70s/it]
#                    all         55       1630      0.907      0.936      0.964      0.629
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/699      13.6G     0.0457      0.116    0.01832       2024        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.75s/it]
#                    all         55       1630      0.922      0.942      0.972      0.662
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/699      13.6G    0.04522     0.1181    0.01828       2078        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.40s/it]
#                    all         55       1630      0.931      0.951      0.976       0.68
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/699      13.6G    0.04593     0.1143    0.01808       1949        608: 100% 32/32 [00:37<00:00,  1.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.53s/it]
#                    all         55       1630       0.92      0.919       0.96      0.658
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/699      13.6G    0.04461     0.1168    0.01808       2193        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.87s/it]
#                    all         55       1630      0.917      0.954       0.97      0.653
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/699      13.6G    0.04439     0.1142    0.01783       2164        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.66s/it]
#                    all         55       1630      0.912       0.94      0.968      0.654
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/699      13.6G    0.04436     0.1144    0.01764       2002        608: 100% 32/32 [00:36<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.61s/it]
#                    all         55       1630       0.92      0.938       0.97      0.673
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/699      13.6G    0.04533     0.1136    0.01786       2093        608: 100% 32/32 [00:36<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.22s/it]
#                    all         55       1630       0.94       0.96      0.978      0.687
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/699      13.6G    0.04502     0.1132    0.01768       2403        608: 100% 32/32 [00:37<00:00,  1.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.58s/it]
#                    all         55       1630      0.922      0.921      0.965      0.651
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/699      13.6G    0.04483     0.1169    0.01783       2122        608: 100% 32/32 [00:37<00:00,  1.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.46s/it]
#                    all         55       1630       0.93      0.952      0.974      0.677
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/699      13.6G    0.04496     0.1145    0.01762       2437        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.62s/it]
#                    all         55       1630      0.925      0.953      0.973      0.663
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/699      13.6G    0.04463      0.113    0.01751       2524        608: 100% 32/32 [00:37<00:00,  1.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.40s/it]
#                    all         55       1630      0.926      0.954      0.973      0.667
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/699      13.6G     0.0443      0.113     0.0176       2273        608: 100% 32/32 [00:35<00:00,  1.10s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.84s/it]
#                    all         55       1630      0.921      0.921      0.963      0.622
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/699      13.6G    0.04454     0.1137    0.01745       2095        608: 100% 32/32 [00:36<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all         55       1630      0.927      0.939      0.969       0.66
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/699      13.6G    0.04443     0.1121    0.01726       2043        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.57s/it]
#                    all         55       1630      0.924      0.933      0.971      0.643
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/699      13.6G    0.04391     0.1124    0.01719       1999        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.37s/it]
#                    all         55       1630      0.926      0.951      0.972      0.665
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/699      13.6G    0.04476     0.1131    0.01747       2250        608: 100% 32/32 [00:38<00:00,  1.21s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.25s/it]
#                    all         55       1630      0.938      0.935      0.968      0.651
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/699      13.6G    0.04334     0.1116    0.01695       2353        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.16s/it]
#                    all         55       1630      0.938      0.953      0.974      0.672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/699      13.6G    0.04354     0.1112    0.01724       2213        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.68s/it]
#                    all         55       1630      0.924      0.946      0.972       0.64
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/699      13.6G    0.04461      0.111    0.01732       2012        608: 100% 32/32 [00:37<00:00,  1.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.75s/it]
#                    all         55       1630      0.918      0.931      0.966      0.622
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/699      13.6G    0.04337     0.1132    0.01707       2216        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.62s/it]
#                    all         55       1630      0.922      0.938       0.97      0.649
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/699      13.6G    0.04381     0.1125    0.01723       1649        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.64s/it]
#                    all         55       1630       0.94      0.952      0.978      0.658
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/699      13.6G    0.04409     0.1097    0.01698       1809        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.33s/it]
#                    all         55       1630      0.932      0.949      0.974      0.616
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/699      13.6G    0.04377     0.1114    0.01701       2075        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all         55       1630      0.935      0.959      0.978      0.665
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/699      13.6G    0.04364     0.1119    0.01694       2114        608: 100% 32/32 [00:37<00:00,  1.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.33s/it]
#                    all         55       1630      0.914      0.939      0.966      0.623
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/699      13.6G    0.04341     0.1107    0.01653       1923        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.13s/it]
#                    all         55       1630      0.923      0.944       0.97      0.608
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/699      13.6G    0.04351     0.1091    0.01675       2006        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all         55       1630      0.923      0.942      0.973      0.637
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/699      13.6G    0.04349       0.11    0.01687       2153        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.24s/it]
# ...
#                    all         55       1630      0.945      0.958      0.979      0.686
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     301/699      13.6G    0.03737    0.08562     0.0132       2063        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.56s/it]
#                    all         55       1630      0.947      0.962       0.98      0.681
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     302/699      13.6G    0.03775    0.08726    0.01335       2004        608: 100% 32/32 [00:36<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.27s/it]
#                    all         55       1630      0.956      0.964      0.981      0.679
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     303/699      13.6G    0.03741    0.08765    0.01321       1732        608: 100% 32/32 [00:36<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.41s/it]
#                    all         55       1630      0.959       0.96      0.983       0.67
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     304/699      13.6G    0.03765    0.08685    0.01341       2461        608: 100% 32/32 [00:36<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.24s/it]
#                    all         55       1630      0.956      0.962      0.982      0.672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     305/699      13.6G    0.03797    0.08686    0.01345       2216        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.94s/it]
#                    all         55       1630      0.946       0.96      0.979      0.672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     306/699      13.6G    0.03843    0.08714    0.01348       2040        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.21s/it]
#                    all         55       1630      0.935      0.943      0.971      0.664
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     307/699      13.6G    0.03794    0.08886    0.01348       2079        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all         55       1630      0.942       0.95      0.974      0.671
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     308/699      13.6G    0.03768    0.08661    0.01333       2016        608: 100% 32/32 [00:36<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.33s/it]
#                    all         55       1630      0.947      0.957      0.979      0.675
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     309/699      13.6G    0.03725    0.08599    0.01327       1786        608: 100% 32/32 [00:34<00:00,  1.08s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.84s/it]
#                    all         55       1630      0.962      0.955      0.981      0.676
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     310/699      13.6G    0.03764    0.08536    0.01322       2542        608: 100% 32/32 [00:35<00:00,  1.10s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.08s/it]
#                    all         55       1630      0.955      0.939      0.976      0.668
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     311/699      13.6G    0.03784    0.08654    0.01341       1933        608: 100% 32/32 [00:38<00:00,  1.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.41s/it]
#                    all         55       1630      0.962      0.962      0.982      0.676
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     312/699      13.6G    0.03772     0.0869    0.01323       2190        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.26s/it]
#                    all         55       1630      0.939      0.924      0.966      0.668
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     313/699      13.6G    0.03744    0.08702    0.01343       1940        608: 100% 32/32 [00:35<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.22s/it]
#                    all         55       1630      0.943      0.943      0.973      0.677
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     314/699      13.6G    0.03808    0.08718    0.01329       1808        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.34s/it]
#                    all         55       1630      0.957      0.961      0.983      0.681
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     315/699      13.6G    0.03801    0.08717    0.01345       1723        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.87s/it]
#                    all         55       1630       0.96      0.964      0.984      0.678
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     316/699      13.6G    0.03741    0.08625    0.01327       2219        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.36s/it]
#                    all         55       1630      0.961      0.969      0.984      0.678
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     317/699      13.6G     0.0373    0.08437    0.01313       2202        608: 100% 32/32 [00:36<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.22s/it]
#                    all         55       1630      0.937      0.965       0.98      0.671
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     318/699      13.6G    0.03755    0.08582    0.01334       2012        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.08s/it]
#                    all         55       1630       0.94      0.937      0.974      0.668
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     319/699      13.6G    0.03786    0.08511    0.01315       2087        608: 100% 32/32 [00:36<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.27s/it]
#                    all         55       1630      0.951      0.957      0.978      0.667
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     320/699      13.6G    0.03741    0.08607    0.01328       1905        608: 100% 32/32 [00:37<00:00,  1.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.29s/it]
#                    all         55       1630      0.947      0.963      0.979      0.664
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     321/699      13.6G    0.03756    0.08586    0.01312       2026        608: 100% 32/32 [00:36<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all         55       1630      0.944      0.953      0.976      0.669
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     322/699      13.6G    0.03742    0.08642    0.01326       2222        608: 100% 32/32 [00:36<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.20s/it]
#                    all         55       1630      0.953      0.951      0.979      0.674
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     323/699      13.6G    0.03753    0.08581    0.01327       1949        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.34s/it]
#                    all         55       1630      0.955      0.953      0.981      0.674
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     324/699      13.6G    0.03768    0.08631    0.01333       2496        608: 100% 32/32 [00:37<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.27s/it]
#                    all         55       1630      0.955       0.96      0.982      0.679
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     325/699      13.6G    0.03723    0.08408    0.01316       1865        608: 100% 32/32 [00:36<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.40s/it]
#                    all         55       1630      0.961      0.964      0.983      0.678
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     326/699      13.6G    0.03751    0.08554     0.0132       2055        608: 100% 32/32 [00:37<00:00,  1.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.75s/it]
#                    all         55       1630      0.946      0.965      0.981      0.672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     327/699      13.6G    0.03718    0.08333    0.01311       2292        608: 100% 32/32 [00:36<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.31s/it]
#                    all         55       1630      0.955       0.95      0.981      0.675
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     328/699      13.6G    0.03728    0.08477    0.01324       2301        608: 100% 32/32 [00:35<00:00,  1.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.22s/it]
#                    all         55       1630      0.947      0.959      0.981      0.672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     329/699      13.6G     0.0373    0.08594    0.01326       2331        608: 100% 32/32 [00:36<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.36s/it]
#                    all         55       1630      0.961      0.965      0.984      0.672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     330/699      13.6G    0.03708    0.08382    0.01312       2154        608: 100% 32/32 [00:34<00:00,  1.09s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.99s/it]
#                    all         55       1630       0.96       0.97      0.985      0.668
# Stopping training early as no improvement observed in last 100 epochs. Best results observed at epoch 230, best model saved as best.pt.
# To update EarlyStopping(patience=100) pass a new patience value, i.e. `python train.py --patience 300` or use `--patience 0` to disable EarlyStopping.
#
# 331 epochs completed in 3.701 hours.
# Optimizer stripped from runs/train/exp7/weights/last.pt, 42.4MB
# Optimizer stripped from runs/train/exp7/weights/best.pt, 42.4MB
#
# Validating runs/train/exp7/weights/best.pt...
# Fusing layers...
# Model summary: 212 layers, 20978205 parameters, 0 gradients, 48.3 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.11s/it]
#                    all         55       1630      0.959      0.968      0.984      0.693
#                     11         55         52      0.963      0.991       0.99      0.712
#                     12         55         51      0.995       0.98      0.995      0.667
#                     13         55         53      0.965      0.981      0.988      0.694
#                     14         55         49      0.891      0.918      0.969      0.681
#                     15         55         49      0.938      0.924      0.982      0.697
#                     16         55         54      0.963      0.971       0.97      0.718
#                     17         55         53      0.923      0.962      0.977      0.699
#                     18         55         44      0.952      0.893       0.95      0.565
#                     21         55         53          1          1      0.995      0.729
#                     22         55         53      0.981      0.995      0.993      0.679
#                     23         55         54      0.964      0.963      0.993        0.7
#                     24         55         51      0.942       0.98      0.982      0.678
#                     25         55         48      0.887      0.979      0.978      0.699
#                     26         55         53      0.994      0.981      0.994      0.687
#                     27         55         54      0.934          1      0.994      0.632
#                     28         55         44          1      0.903      0.971      0.576
#                     31         55         54      0.959      0.926       0.97      0.605
#                     32         55         55      0.978      0.982      0.989      0.655
#                     33         55         55       0.96          1      0.995      0.692
#                     34         55         49      0.959       0.98      0.991      0.739
#                     35         55         52      0.976          1      0.994       0.73
#                     36         55         46      0.932      0.978      0.991       0.78
#                     37         55         51      0.981      0.987      0.986       0.74
#                     38         55         47      0.999          1      0.995      0.732
#                     41         55         55      0.973      0.964      0.978      0.585
#                     42         55         56          1      0.982      0.988       0.68
#                     43         55         55      0.981      0.923      0.992      0.729
#                     44         55         48      0.886      0.958      0.984       0.69
#                     45         55         51       0.98      0.967      0.993      0.728
#                     46         55         46      0.949      0.978      0.984      0.793
#                     47         55         50      0.922       0.95      0.956      0.749
#                     48         55         45      0.978      0.968      0.986      0.733
# Results saved to runs/train/exp7

# %%
ls
# Out:
# benchmarks.py    detect.py         models/           runs/           utils/
# CITATION.cff     Deteksi-Gigi--5/  __pycache__/      segment/        val.py
# classify/        export.py         README.md         setup.cfg       yolov5m.pt
# CONTRIBUTING.md  hubconf.py        README.zh-CN.md   train.py        yolov5s.pt
# data/            LICENSE           requirements.txt  tutorial.ipynb

# %%
*unnecessary

# %%
log_model(experiment, model, model_name="TheModel")

# %%
Show grafik

# %%
# !kill 25352

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %reload_ext tensorboard
# %tensorboard --logdir runs

# %% [markdown]
# Proses testing

# %%
# !python detect.py --weights runs/train/exp7/weights/best.pt --img 608 --conf 0.1 --source {dataset.location}/test/images
# !python detect.py --weights best-aby.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['runs/train/exp7/weights/best.pt'], source=/content/datasets/Deteksi-Gigi--12/test/images, data=data/coco128.yaml, imgsz=[608, 608], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 212 layers, 20978205 parameters, 0 gradients, 48.3 GFLOPs
# image 1/45 /content/datasets/Deteksi-Gigi--12/test/images/12_jpg.rf.6c2daac797beb1cafcce317d678f87ff.jpg: 320x608 2 11s, 1 12, 1 13, 1 14, 2 15s, 2 16s, 1 17, 1 21, 1 22, 1 23, 2 24s, 1 25, 1 26, 1 27, 1 31, 2 32s, 2 33s, 1 34, 1 35, 1 36, 1 37, 1 38, 1 41, 1 42, 1 43, 1 44, 1 45, 1 46, 2 47s, 1 48, 800.5ms
# image 41/45 /content/datasets/Deteksi-Gigi--12/test/images/94_JPG.rf.8edd050d18fa767fd51238ce03624b8b.jpg: 352x608 1 11, 1 12, 2 13s, 2 14s, 2 15s, 1 16, 2 17s, 1 18, 1 21, 1 22, 1 23, 1 24, 1 25, 2 26s, 1 27, 1 28, 1 31, 2 32s, 1 33, 2 34s, 2 35s, 1 36, 2 37s, 1 38, 1 41, 2 42s, 1 43, 1 44, 1 45, 1 46, 1 47, 2 48s, 527.8ms
# image 42/45 /content/datasets/Deteksi-Gigi--12/test/images/96_JPG.rf.d0e24591bc5a44bcb4acf5ee62fe750b.jpg: 352x608 1 11, 1 12, 1 13, 1 14, 1 15, 1 16, 2 17s, 1 18, 1 21, 1 22, 1 23, 1 24, 1 25, 1 26, 1 27, 1 28, 1 31, 1 32, 1 33, 1 34, 1 35, 1 36, 1 37, 1 38, 1 41, 1 42, 2 43s, 1 44, 2 45s, 1 46, 1 47, 1 48, 694.8ms
# image 43/45 /content/datasets/Deteksi-Gigi--12/test/images/97_JPG.rf.ac9d0ecfe3cddf5c571d629d88f20d9c.jpg: 352x608 1 11, 1 12, 1 13, 1 14, 1 15, 1 16, 1 17, 1 18, 1 21, 2 22s, 1 23, 1 24, 1 25, 1 26, 1 27, 1 28, 1 31, 1 32, 1 33, 1 34, 1 35, 1 36, 1 37, 1 41, 1 42, 1 43, 1 44, 2 45s, 1 46, 1 47, 723.8ms
# image 44/45 /content/datasets/Deteksi-Gigi--12/test/images/98_JPG.rf.46b92eb2d49ce0af03664649ca0cc42c.jpg: 352x608 2 11s, 1 12, 1 13, 1 14, 2 15s, 1 16, 1 17, 2 18s, 1 21, 1 22, 1 23, 1 24, 2 25s, 1 26, 2 27s, 1 28, 2 31s, 2 32s, 1 33, 1 34, 1 35, 1 36, 2 37s, 1 41, 1 42, 1 43, 1 44, 2 45s, 1 46, 1 47, 1 48, 912.8ms
# image 45/45 /content/datasets/Deteksi-Gigi--12/test/images/99_JPG.rf.e7ff7c100fcabafe2dd4778659569673.jpg: 352x608 1 11, 1 12, 1 13, 1 14, 1 15, 1 16, 1 17, 2 18s, 1 21, 2 22s, 1 23, 1 24, 1 25, 1 26, 1 27, 1 28, 1 31, 1 32, 1 33, 1 34, 1 35, 1 36, 2 37s, 1 38, 1 41, 1 42, 1 43, 1 44, 2 45s, 1 46, 1 47, 2 48s, 883.5ms
# Speed: 0.8ms pre-process, 596.8ms inference, 1.8ms NMS per image at shape (1, 3, 608, 608)
# Results saved to runs/detect/exp

# %% [markdown]
# Lihat gambar setelah di testing

# %%
# display inference on ALL test images
import glob
from IPython.display import Image, display

# for imageName in glob.glob('/content/yolov5/runs/detect/' + expName + '/*.jpg'): #assuming JPG
#     display(Image(filename=imageName))
#     print("\n")
for imageName in glob.glob('/content/yolov5/runs/detect/' + expName + '/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# *unnecessary

# %%
# %ls
# !cp ./ /content/drive/MyDrive/PALJ/COBA-YOLO/YOLOV5
# !cp -r . /content/drive/MyDrive/PALJ/COBA-YOLO/YOLOV5/yolov5/

# %% [markdown]
# *unnecessary

# %%
#export your model's weights for future use
from google.colab import files
files.download('./runs/train/exp/weights/best.pt')

# %% [markdown]
# *unnecessary

# %%
import shutil
import os

# Set the path to the folder containing the files
# folder_path = './runs/detect/' + expName + '/'
folder_path = './'

# Get a list of all files in the folder
file_list = os.listdir(folder_path)

# Create a ZIP file to store the folder contents
shutil.make_archive('/content/folder_download', 'zip', folder_path)

# Download the ZIP file
from google.colab import files
files.download('/content/folder_download.zip')

# %%
# !python val.py --weights runs/train/exp7/weights/best.pt --data /content/datasets/Deteksi-Gigi--12/data.yaml --img 608
# Out:
# val: data=/content/datasets/Deteksi-Gigi--12/data.yaml, weights=['runs/train/exp7/weights/best.pt'], batch_size=32, imgsz=608, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 212 layers, 20978205 parameters, 0 gradients, 48.3 GFLOPs
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 13.0MB/s]
# val: Scanning /content/datasets/Deteksi-Gigi--12/valid/labels... 55 images, 0 backgrounds, 0 corrupt: 100% 55/55 [00:00<00:00, 738.00it/s]
# val: New cache created: /content/datasets/Deteksi-Gigi--12/valid/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:54<00:00, 27.28s/it]
#                    all         55       1630      0.957      0.965      0.983      0.693
#                     11         55         52      0.959          1      0.989      0.714
#                     12         55         51      0.999       0.98      0.995      0.679
#                     13         55         53      0.966      0.962      0.987      0.687
#                     14         55         49      0.892      0.918      0.961      0.681
#                     15         55         49      0.937      0.904      0.977      0.686
#                     16         55         54      0.963      0.981       0.97      0.717
#                     17         55         53      0.936      0.962      0.977      0.686
#                     18         55         44       0.95      0.886      0.946      0.558
#                     21         55         53       0.98      0.981      0.995      0.731
#                     22         55         53      0.978          1      0.993      0.678
#                     23         55         54      0.981      0.978      0.993      0.689
#                     24         55         51      0.943      0.965      0.982      0.683
#                     25         55         48      0.893      0.979      0.976      0.696
#                     26         55         53       0.98      0.981      0.994      0.688
#                     27         55         54      0.945          1      0.992      0.634
#                     28         55         44          1      0.914      0.973      0.587
#                     31         55         54      0.959      0.926      0.969      0.612
#                     32         55         55      0.964      0.981      0.989      0.667
#                     33         55         55      0.949          1      0.995      0.697
#                     34         55         49      0.959      0.966      0.993      0.753
#                     35         55         52      0.976          1      0.995      0.739
#                     36         55         46      0.928      0.978      0.985      0.783
#                     37         55         51      0.954          1      0.985       0.75
#                     38         55         47      0.994      0.979      0.995      0.724
#                     41         55         55      0.973      0.964      0.976      0.587
#                     42         55         56          1      0.982      0.988      0.682
#                     43         55         55      0.981      0.917      0.992      0.726
#                     44         55         48      0.897      0.958      0.981       0.68
#                     45         55         51      0.961      0.961      0.992      0.725
#                     46         55         46      0.949      0.978      0.988      0.792
#                     47         55         50      0.922      0.949      0.962      0.748
#                     48         55         45       0.96      0.956      0.985      0.732
# Speed: 6.1ms pre-process, 937.4ms inference, 34.2ms NMS per image at shape (32, 3, 608, 608)
# Results saved to runs/val/exp

# %%
ls /content
# Out:
# datasets/  drive/  drive-yolo@  sample_data/
